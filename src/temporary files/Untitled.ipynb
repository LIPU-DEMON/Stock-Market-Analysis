# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder,MinMaxScaler

# %%
data = pd.read_csv("Data/Transformed.csv")
data
# Out:
#        Stocks_Apple  Stocks_GeneralElectric  Stocks_IBM  \
# 0                 1                       0           0
# 1                 1                       0           0
# 2                 1                       0           0
# 3                 1                       0           0
# 4                 1                       0           0
# ...             ...                     ...         ...
# 25130             0                       0           0
# 25131             0                       0           0
# 25132             0                       0           0
# 25133             0                       0           0
# 25134             0                       0           0
#
#        Stocks_Johnson&Johnson  Stocks_Microsoft        Date      Open  \
# 0                           0                 0  2005-07-28  0.000159
# 1                           0                 0  2005-07-29  0.000125
# 2                           0                 0  2005-08-01  0.000009
# ...

# %%
data.tail(60).drop(columns=["Date"]).values
# Out:
# array([[0.        , 0.        , 0.        , 1.        , 0.        ,
#         0.89218875, 0.88684988, 0.88465409, 0.04375669, 0.88906705],
#        [0.        , 0.        , 0.        , 1.        , 0.        ,
#         0.9006189 , 0.89329905, 0.89445797, 0.02480017, 0.89452039],
#        [0.        , 0.        , 0.        , 1.        , 0.        ,
#         0.90026166, 0.90187433, 0.89782121, 0.02098997, 0.89848642],
#        [0.        , 0.        , 0.        , 1.        , 0.        ,
#         0.91990832, 0.91023689, 0.9030452 , 0.05015462, 0.90131925],
#        [0.        , 0.        , 0.        , 1.        , 0.        ,
#         0.8970468 , 0.88819644, 0.89116615, 0.03492453, 0.88821723],
#        [0.        , 0.        , 0.        , 1.        , 0.        ,
#         0.90469117, 0.89974821, 0.90318826, 0.02586784, 0.89997363],
#        [0.        , 0.        , 0.        , 1.        , 0.        ,
#         0.90897766, 0.90024426, 0.90096991, 0.02244703, 0.89204157],
# ...

# %%
cols = data.columns[2:11]
for i in cols:
    minmax= MinMaxScaler()
    scale = minmax.fit_transform(data[[i]])
    data.loc[:,i] = scale.astype("float")
data
# Out:
# C:\Users\lipun\AppData\Local\Temp\ipykernel_19020\3840753318.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.02866333 0.0269985  0.03507466 ... 0.05145753 0.04114551 0.04800656]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,i] = scale.astype("float")
#                Stocks        Date      Open      High       Low    Volume  \
# 0     Johnson&Johnson  2005-07-28  0.050660  0.049402  0.053655  0.028663
# 1     Johnson&Johnson  2005-07-29  0.051469  0.049161  0.052925  0.026998
# 2     Johnson&Johnson  2005-08-01  0.049729  0.051450  0.054182  0.035075
# 3     Johnson&Johnson  2005-08-02  0.051307  0.048880  0.053858  0.023055
# 4     Johnson&Johnson  2005-08-03  0.050255  0.050084  0.054425  0.019942
# ...               ...         ...       ...       ...       ...       ...
# 5022  Johnson&Johnson  2025-07-16  0.944729  0.976459  0.947055  0.134177
# ...

# %%
data.to_csv("jnj_scaled",index=False)

# %%
df_microsoft = pd.read_csv("msft_scaled")
df_microsoft = df_microsoft.iloc[:,2:11]
df_microsoft.columns
# Out:
# Index(['Open', 'High', 'Low', 'Volume', 'Close', 'SMA_7', 'EMA_7', 'RSI_7',
#        'WVAP'],
#       dtype='object')

# %%
df_microsoft
# Out:
# array([[1.33086193e-02, 1.28349365e-02, 1.38554075e-02, ...,
#         0.00000000e+00, 0.00000000e+00, 8.86968357e-04],
#        [1.33500872e-02, 1.30423320e-02, 1.37573256e-02, ...,
#         0.00000000e+00, 0.00000000e+00, 7.53183529e-04],
#        [1.33915463e-02, 1.31114568e-02, 1.39955199e-02, ...,
#         0.00000000e+00, 0.00000000e+00, 1.48270927e-03],
#        ...,
#        [1.00000000e+00, 1.00000000e+00, 1.00000000e+00, ...,
#         9.98112011e-01, 7.73149847e-01, 9.99062242e-01],
#        [9.84560850e-01, 9.94931606e-01, 9.96213171e-01, ...,
#         1.00000000e+00, 7.73313170e-01, 9.99535953e-01],
#        [9.93025589e-01, 9.93162599e-01, 9.95649179e-01, ...,
#         9.99054927e-01, 5.77333390e-01, 1.00000000e+00]])
